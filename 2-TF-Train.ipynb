# %% [markdown]
# # **TRAINING**

# %% [markdown]
# # Step 1: Clean the XML

# %% [markdown]
# ## this will create a new directory under ./images called cleaned. Once script is run copy the contents back to /images overwriting the existing xml

# %%
# !python xmlconversion.py --verbose
# Out:
# images/Erithacus_Rubecula_974.xml
# images/Periparus_ater_936.xml
# images/Erithacus_Rubecula_791.xml
# images/Erithacus_Rubecula_512.xml
# images/Pica_pica354.xml
# images/Periparus_ater_1050.xml
# images/Pica_pica899.xml
# images/Periparus_ater_1083.xml
# images/Pica_pica510.xml
# images/Pica_pica641.xml
# images/Periparus_ater_973.xml
# images/Pica_pica418.xml
# images/Erithacus_Rubecula_181.xml
# images/Pica_pica256.xml
# images/Periparus_ater_985.xml
# images/Pica_pica190.xml
# images/Pica_pica608.xml
# images/Erithacus_Rubecula_97.xml
# images/Erithacus_Rubecula_218.xml
# images/Periparus_ater_1230.xml
# images/Periparus_ater_46.xml
# images/Erithacus_Rubecula_170.xml
# images/Erithacus_Rubecula_800.xml
# images/Erithacus_Rubecula_238.xml
# images/Periparus_ater_1079.xml
# images/Erithacus_Rubecula_514.xml
# images/Pica_pica647.xml
# images/Pica_pica554.xml
# images/Erithacus_Rubecula_46.xml
# images/Erithacus_Rubecula_337.xml
# images/Pica_pica735.xml
# ...

# %% [markdown]
# # Step 2: Patition the train / test split 90/10

# %%
# !python partition_dataset.py -x -i ./images -r 0.1

# %% [markdown]
# # Step 3: Create the TF Record

# %% [markdown]
# ### Update the .PBTXT file

# %%
# !code './data/label_map.pbtxt'

# %% [markdown]
# ### Create the TF Record (Train)

# %%
# !python generate_tfrecord.py -x images/train -l data/label_map.pbtxt -o data/train.record
# Out:
# Successfully created the TFRecord file: data/train.record

# %% [markdown]
# ### Create the TF Record (Test)

# %%
# !python generate_tfrecord.py -x images/test -l data/label_map.pbtxt -o data/test.record
# Out:
# Successfully created the TFRecord file: data/test.record

# %% [markdown]
# # Step 4: Set the model path

# %%
#PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"
#PATH_TO_MODEL = "ssd_resnet50_v1_fpn_1024x1024_coco17_tpu-8"
#PATH_TO_MODEL = "ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8"
#PATH_TO_MODEL = "efficientdet_d1_coco17_tpu-32"
#PATH_TO_MODEL = "ssd_resnet101_v1_fpn_1024x1024_coco17_tpu-8"
PATH_TO_MODEL = "faster_rcnn_inception_resnet_v2_1024x1024_coco17_tpu-8"

# %% [markdown]
# # Step 5: Configure the config file

# %%
# !code './training/TF2/training/'{PATH_TO_MODEL}'/pipeline.config'

# %% [markdown]
# # Step 6: Training

# %%
# !python model_main_tf2.py --model_dir=training/TF2/training/{PATH_TO_MODEL} --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --num_train_steps=15000 --alsologtostderr
# Out:
# 2023-01-12 20:23:33.330356: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-12 20:23:34.917078: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-01-12 20:23:34.943747: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-12 20:23:34.944367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.755GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-01-12 20:23:34.944391: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %% [markdown]
# # Step 7: Exporting a Trained Inference Graph

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path ./training/TF2/training/{PATH_TO_MODEL}/pipeline.config --trained_checkpoint_dir ./training/TF2/training/{PATH_TO_MODEL}/ --output_directory ./training/TF2/training/{PATH_TO_MODEL}/saved_model/
# Out:
# 2023-01-12 20:32:07.118917: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-12 20:32:09.161820: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-01-12 20:32:09.192005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-12 20:32:09.192507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.755GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-01-12 20:32:09.192527: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
